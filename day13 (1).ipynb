# %%
#Q1,Q2
from datetime import *
future_date=input("yyyymmdd: ")
future_dte=date(int(future_date[4:8]), int(future_date[2:4]),int(future_date[0:2]))
dte=date.today()
# print(dte)
delta_days= abs((future_dte-dte).days)
print(delta_days)


future_time=input("hr:min:sec: ")
future_tme=(int(future_time[0:2]), int(future_time[2:4]), int(future_time[4:6]))
ft=time(future_tme)
tme=datetime.now().time()
x = tme.strftime("%H:%M:%S")
time_to_go= (x-ft).time

# %%
#Q3 and Q4
import pandas as pd
df = pd.read_csv("D:\Python\students.csv")
#print(df['Marks'])
avg=sum((df['Marks']))/len((df['Marks']))
print(f" Average marks:{avg}")
input_name=input("Enter name to check if it exists: ").lower()
print('input_name' in df['Student_name'])
# Out:
#  Average marks:18.0
# Enter name to check if it exists: hanesh
# False

# %%
#Q5
import datetime
event={"e1": '12-10-2022' , "e2":'26-09-1995', "e3":'23-06-2022'}
eve=input("Enter date in dd-mm-yyyy: ")
eve=eve.split("-")
print(eve)
dte= datetime.datetime(int(eve[2]), int(eve[1]), int(eve(0))
print(dte)
# key_list=[]
# val_list=[]
# for i in event.keys():
#     if i==event.keys():
#         return True
#     else:
#         return False
# Out:
#   Cell In [51], line 8
#     print(dte)
#     ^
# SyntaxError: invalid syntax

# %%
#Q6
dff=pd.read_csv("D:\Python\students.csv")
#dff.head()
#dff.info()
marks_avg=dff["Marks"].mean()
marks_mode=dff['Marks'].mode()
marks_med=dff["Marks"].median()
print(marks_avg)
print(marks_mode)
print(marks_med)
dff.describe()
# Out:
# 18.0
# 0    2
# Name: Marks, dtype: int64
# 2.0
#             Marks
# count    6.000000
# mean    18.000000
# std     40.179597
# min      0.000000
# 25%      2.000000
# 50%      2.000000
# 75%      2.000000
# max    100.000000

# %%
#Q7 Using the same students.csv
dff=pd.read_csv("D:\Python\students.csv")
df2=dff["Student_name"]
#df2.info()
df3=list(df2)
df3=set(df3)
df3=list(df3)


from itertools import permutations
l = list(permutations(df3))
print(l)
# Out:
# [('Hany', 'Hanymol', 'Syed', 'Hanesh', 'Akshay', 'Ponty'), ('Hany', 'Hanymol', 'Syed', 'Hanesh', 'Ponty', 'Akshay'), ('Hany', 'Hanymol', 'Syed', 'Akshay', 'Hanesh', 'Ponty'), ('Hany', 'Hanymol', 'Syed', 'Akshay', 'Ponty', 'Hanesh'), ('Hany', 'Hanymol', 'Syed', 'Ponty', 'Hanesh', 'Akshay'), ('Hany', 'Hanymol', 'Syed', 'Ponty', 'Akshay', 'Hanesh'), ('Hany', 'Hanymol', 'Hanesh', 'Syed', 'Akshay', 'Ponty'), ('Hany', 'Hanymol', 'Hanesh', 'Syed', 'Ponty', 'Akshay'), ('Hany', 'Hanymol', 'Hanesh', 'Akshay', 'Syed', 'Ponty'), ('Hany', 'Hanymol', 'Hanesh', 'Akshay', 'Ponty', 'Syed'), ('Hany', 'Hanymol', 'Hanesh', 'Ponty', 'Syed', 'Akshay'), ('Hany', 'Hanymol', 'Hanesh', 'Ponty', 'Akshay', 'Syed'), ('Hany', 'Hanymol', 'Akshay', 'Syed', 'Hanesh', 'Ponty'), ('Hany', 'Hanymol', 'Akshay', 'Syed', 'Ponty', 'Hanesh'), ('Hany', 'Hanymol', 'Akshay', 'Hanesh', 'Syed', 'Ponty'), ('Hany', 'Hanymol', 'Akshay', 'Hanesh', 'Ponty', 'Syed'), ('Hany', 'Hanymol', 'Akshay', 'Ponty', 'Syed', 'Hanesh'), ('Hany', 'Hanymol', 'Akshay', 'Ponty', 'Hanesh', 'Syed'), ('Hany', 'Hanymol', 'Ponty', 'Syed', 'Hanesh', 'Akshay'), ('Hany', 'Hanymol', 'Ponty', 'Syed', 'Akshay', 'Hanesh'), ('Hany', 'Hanymol', 'Ponty', 'Hanesh', 'Syed', 'Akshay'), ('Hany', 'Hanymol', 'Ponty', 'Hanesh', 'Akshay', 'Syed'), ('Hany', 'Hanymol', 'Ponty', 'Akshay', 'Syed', 'Hanesh'), ('Hany', 'Hanymol', 'Ponty', 'Akshay', 'Hanesh', 'Syed'), ('Hany', 'Syed', 'Hanymol', 'Hanesh', 'Akshay', 'Ponty'), ('Hany', 'Syed', 'Hanymol', 'Hanesh', 'Ponty', 'Akshay'), ('Hany', 'Syed', 'Hanymol', 'Akshay', 'Hanesh', 'Ponty'), ('Hany', 'Syed', 'Hanymol', 'Akshay', 'Ponty', 'Hanesh'), ('Hany', 'Syed', 'Hanymol', 'Ponty', 'Hanesh', 'Akshay'), ('Hany', 'Syed', 'Hanymol', 'Ponty', 'Akshay', 'Hanesh'), ('Hany', 'Syed', 'Hanesh', 'Hanymol', 'Akshay', 'Ponty'), ('Hany', 'Syed', 'Hanesh', 'Hanymol', 'Ponty', 'Akshay'), ('Hany', 'Syed', 'Hanesh', 'Akshay', 'Hanymol', 'Ponty'), ('Hany', 'Syed', 'Hanesh', 'Akshay', 'Ponty', 'Hanymol'), ('Hany', 'Syed', 'Hanesh', 'Ponty', 'Hanymol', 'Akshay'), ('Hany', 'Syed', 'Hanesh', 'Ponty', 'Akshay', 'Hanymol'), ('Hany', 'Syed', 'Akshay', 'Hanymol', 'Hanesh', 'Ponty'), ('Hany', 'Syed', 'Akshay', 'Hanymol', 'Ponty', 'Hanesh'), ('Hany', 'Syed', 'Akshay', 'Hanesh', 'Hanymol', 'Ponty'), ('Hany', 'Syed', 'Akshay', 'Hanesh', 'Ponty', 'Hanymol'), ('Hany', 'Syed', 'Akshay', 'Ponty', 'Hanymol', 'Hanesh'), ('Hany', 'Syed', 'Akshay', 'Ponty', 'Hanesh', 'Hanymol'), ('Hany', 'Syed', 'Ponty', 'Hanymol', 'Hanesh', 'Akshay'), ('Hany', 'Syed', 'Ponty', 'Hanymol', 'Akshay', 'Hanesh'), ('Hany', 'Syed', 'Ponty', 'Hanesh', 'Hanymol', 'Akshay'), ('Hany', 'Syed', 'Ponty', 'Hanesh', 'Akshay', 'Hanymol'), ('Hany', 'Syed', 'Ponty', 'Akshay', 'Hanymol', 'Hanesh'), ('Hany', 'Syed', 'Ponty', 'Akshay', 'Hanesh', 'Hanymol'), ('Hany', 'Hanesh', 'Hanymol', 'Syed', 'Akshay', 'Ponty'), ('Hany', 'Hanesh', 'Hanymol', 'Syed', 'Ponty', 'Akshay'), ('Hany', 'Hanesh', 'Hanymol', 'Akshay', 'Syed', 'Ponty'), ('Hany', 'Hanesh', 'Hanymol', 'Akshay', 'Ponty', 'Syed'), ('Hany', 'Hanesh', 'Hanymol', 'Ponty', 'Syed', 'Akshay'), ('Hany', 'Hanesh', 'Hanymol', 'Ponty', 'Akshay', 'Syed'), ('Hany', 'Hanesh', 'Syed', 'Hanymol', 'Akshay', 'Ponty'), ('Hany', 'Hanesh', 'Syed', 'Hanymol', 'Ponty', 'Akshay'), ('Hany', 'Hanesh', 'Syed', 'Akshay', 'Hanymol', 'Ponty'), ('Hany', 'Hanesh', 'Syed', 'Akshay', 'Ponty', 'Hanymol'), ('Hany', 'Hanesh', 'Syed', 'Ponty', 'Hanymol', 'Akshay'), ('Hany', 'Hanesh', 'Syed', 'Ponty', 'Akshay', 'Hanymol'), ('Hany', 'Hanesh', 'Akshay', 'Hanymol', 'Syed', 'Ponty'), ('Hany', 'Hanesh', 'Akshay', 'Hanymol', 'Ponty', 'Syed'), ('Hany', 'Hanesh', 'Akshay', 'Syed', 'Hanymol', 'Ponty'), ('Hany', 'Hanesh', 'Akshay', 'Syed', 'Ponty', 'Hanymol'), ('Hany', 'Hanesh', 'Akshay', 'Ponty', 'Hanymol', 'Syed'), ('Hany', 'Hanesh', 'Akshay', 'Ponty', 'Syed', 'Hanymol'), ('Hany', 'Hanesh', 'Ponty', 'Hanymol', 'Syed', 'Akshay'), ('Hany', 'Hanesh', 'Ponty', 'Hanymol', 'Akshay', 'Syed'), ('Hany', 'Hanesh', 'Ponty', 'Syed', 'Hanymol', 'Akshay' ...

# %%
#Q8
add_to_file=input('what to add to file: ')
file=open("D:\Python\q8.txt", "w")
file.write(add_to_file)
file.close()
file=open("D:\Python\q8.txt", 'r')
file.read()

# %%
#Q9
import requests
rt=requests.get(input("Enter url: "))

file=open("D:\Python\q9.txt", "wb").write(rt.content)


file1 = open("D:\Python\q9.txt","r+") 
print('File content: ', file1.read())
# Out:
# Enter url: https://athleticinterest.com/
# File content:  <!doctype html>
# <html lang="de-DE" class="no-js" itemscope itemtype="http://schema.org/WebPage">
# 	<head>
# 		<meta charset="UTF-8">
# 		<title>Athletic Interest â€“ The Business of Sports</title>
#
# 		<link href="//www.google-analytics.com" rel="dns-prefetch">
#         <link href="https://athleticinterest.com/wp-content/themes/athleticinterest2022/img/icons/favicon.ico" rel="shortcut icon">
#         <link href="https://athleticinterest.com/wp-content/themes/athleticinterest2022/img/icons/touch.png" rel="apple-touch-icon-precomposed">
#
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0">
#
# 		<meta name='robots' content='index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1' />
#
# 	<!-- This site is optimized with the Yoast SEO plugin v19.8 - https://yoast.com/wordpress/plugins/seo/ -->
# 	<meta name="description" content="We create beautiful video essays to share our passion for sports &amp; business. We are one of the fastest-growing sports channels on YouTube." />
# 	<link rel="canonical" href="https://athleticinterest.com/" />
# 	<meta property="og:locale" content="de_DE" />
# 	<meta property="og:type" content="website" />
# 	<meta property="og:title" content="Athletic Interest â€“ The Business of Sports" />
# 	<meta property="og:description" content="We create beautiful video essays to share our passion for sports &amp; business. We are one of the fastest-growing sports channels on YouTube." />
# 	<meta property="og:url" content="https://athleticinterest.com/" />
# 	<meta property="og:site_name" content="Athletic Interest" />
# 	<meta property="article:modified_time" content="2022-10-19T22:59:31+00:00" />
# 	<meta name="twitter:card" content="summary_large_image" />
# 	<meta name="twitter:image" content="https://athleticinterest.com/wp-content/uploads/share.png" />
# 	<meta name="twitter:label1" content="GeschÃ¤tzte Lesezeit" />
# 	<meta name="twitter:data1" content="1 Minute" />
# 	<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":"WebPage","@id":"https://athleticinterest.com/","url":"https://athleticinterest.com/","name":"Athletic Interest â€“ The Business of Sports","isPartOf":{"@id":"https://athleticinterest.com/#website"},"primaryImageOfPage":{"@id":"https://athleticinterest.com/#primaryimage"},"image":{"@id":"https://athleticinterest.com/#primaryimage"},"thumbnailUrl":"https://athleticinterest.com/wp-content/uploads/share.png","datePublished":"2022-07-11T12:15:44+00:00","dateModified":"2022-10-19T22:59:31+00:00","description":"We create beautiful video essays to share our passion for sports & business. We are one of the fastest-growing sports channels on YouTube.","breadcrumb":{"@id":"https://athleticinterest.com/#breadcrumb"},"inLanguage":"de-DE","potentialAction":[{"@type":"ReadAction","target":["https://athleticinterest.com/"]}]},{"@type":"ImageObject","inLanguage":"de-DE","@id":"https://athleticinterest.com/#primaryimage","url":"https://athleticinterest.com/wp-content/uploads/share.png","contentUrl":"https://athleticinterest.com/wp-content/uploads/share.png","width":1200,"height":630},{"@type":"BreadcrumbList","@id":"https://athleticinterest.com/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home"}]},{"@type":"WebSite","@id":"https://athleticinterest.com/#website","url":"https://athleticinterest.com/","name":"Athletic Interest","description":"","potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://athleticinterest.com/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"de-DE"}]}</script>
# 	<!-- / Yoast SEO plugin. -->
#
#
# <link rel='stylesheet' id='wp-block-library-css'  href='https://athleticinterest.com/wp-includes/css/dist/block-library/style.min.css' media='all' />
# <style id='global-styles-inline-css' type='text/css'>
# body{--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--duotone--dark-grayscale: url('#wp-duotone-dark-grayscale');--wp--preset--duotone--grayscale: url('#wp-duotone-grayscale');--wp--preset--duotone--purple-yellow: url('#wp-duotone-purple-yellow');--wp--preset--duotone--blue-red: url('#wp-duotone-blue-red');--wp--preset--duotone--midnight: url('#wp-duotone-midnight');--wp--preset--duotone--magenta-yellow: url('#wp-duotone-magenta-yellow');--wp--preset--duotone--purple-green: url('#wp-duotone-purple-green');--wp--preset--duotone--blue-orange: url('#wp-duotone-blue-orange');--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;}.has-black-color{color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-color{color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-color{color: var(--wp--preset--color--white) !important;}.has-pale-pink-color{color: var(--wp--preset--color--pale-pink) !important;}.has-vivid-red-color{color: var(--wp--preset--color--vivid-red) !important;}.has-luminous-vivid-orange-color{color: var(--wp--preset--color--luminous-vivid-orange) !important;}.has-luminous-vivid-amber-color{color: var(--wp--preset--color--luminous-vivid-amber) !important;}.has-light-green-cyan-color{color: var(--wp--preset--color--light-green-cyan) !important;}.has-vivid-green-cyan-color{color: var(--wp--preset--color--vivid-green-cyan) !important;}.has-pale-cyan-blue-color{color: var(--wp--preset--color--pale-cyan-blue) !important;}.has-vivid-cyan-blue-color{color: var(--wp--preset--color--vivid-cyan-blue) !important;}.has-vivid-purple-color{color: var(--wp--preset--color--vivid-purple) !important;}.has-black-background-color{background-color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-background-color{background-color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-background-color{background-color: var(- ...
# </style>
# <link rel='stylesheet' id='global-css'  href='https://athleticinterest.com/wp-content/cache/autoptimize/css/autoptimize_single_1363914936940aace9e3b2a66fe95a80.css' media='all' />
# <link rel='stylesheet' id='borlabs-cookie-css'  href='https://athleticinterest.com/wp-content/cache/autoptimize/css/autoptimize_single_8180b4d8feeea75299915dce8c29d0f0.css' media='all' />
# <script type='text/javascript' src='https://athleticinterest.com/wp-content/themes/athleticinterest2022/js/lib/modernizr-custom.js' id='modernizr-js'></script>
# <script type='text/javascript' src='https://athleticinterest.com/wp-includes/js/jquery/jquery.min.js' id='jquery-core-js'></script>
# <script type='text/javascript' src='https://athleticinterest.com/wp-includes/js/jquery/jquery-migrate.min.js' id='jquery-migrate-js'></script>
# <link rel="https://api.w.org/" href="https://athleticinterest.com/wp-json/" /><link rel="alternate" type="application/json" href="https://athleticinterest.com/wp-json/wp/v2/pages/2" /><link rel="alternate" type="application/json+oembed" href="https://athleticinterest.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fathleticinterest.com%2F" />
# <link rel="alternate" type="text/xml+oembed" href="https://athleticinterest.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fathleticinterest.com%2F&#038;format=xml" />
#
#         <script type="text/javascript">
#             var jQueryMigrateHelperHasSentDowngrade = false;
#
# 			window.onerror = function( msg, url, line, col, error ) {
# 				// Break out early, do not processing if a downgrade reqeust was already sent.
# 				if ( jQueryMigrateHelperHasSentDowngrade ) {
# 					return true;
#                 }
#
# 				var xhr = new XMLHttpRequest();
# 				var nonce = '5c1057ee45';
# 				var jQueryFunctions = [
# 					'andSelf',
# 					'browser',
# 					'live',
# 					'boxModel',
# 					'support.boxModel',
# 					'size',
# 					'swap',
# 					'clean',
# 					'sub',
#                 ];
# 				var match_pattern = /\)\.(.+?) is not a function/;
#                 var erroredFunction = msg.match( match_pattern );
#
#                 // If there was no matching functions, do not try to downgrade.
#                 if ( typeof erroredFunction !== 'object' || typeof erroredFunction[1] === "undefined" || -1 === jQueryFunctions.indexOf( erroredFunction[1] ) ) {
#                     return true;
#                 }
#
#                 // Set that we've now attempted a downgrade request.
#                 jQueryMigrateHelperHasSentDowngrade = true;
#
# 				xhr.open( 'POST', 'https://athleticinterest.com/wp-admin/admin-ajax.php' );
# 				xhr.setRequestHeader( 'Content-Type', 'application/x-www-form-urlencoded' );
# 				xhr.onload = function () {
# 					var response,
#                         reload = false;
#
# 					if ( 200 === xhr.status ) {
#                         try {
#                         	response = JSON.parse( xhr.response );
#
#                         	reload = response.data.reload;
#                         } catch ( e ) {
#                         	reload = false;
#                         }
#                     }
#
# 					// Automatically reload the page if a deprecation caused an automatic downgrade, ensure visitors get the best possible experience.
# 					if ( reload ) {
# 						location.reload();
#                     }
# 				};
#
# 				xhr.send( encodeURI( 'action=jquery-migrate-downgrade-version&_wpnonce=' + nonce ) );
#
# 				// Suppress error alerts in older browsers
# 				return true;
# 			}
#         </script>
#
# 		<link rel="icon" href="https://athleticinterest.com/wp-content/uploads/cropped-siteicon-32x32.png" sizes="32x32" />
# <link rel="icon" href="https://athleticinterest.com/wp-content/uploads/cropped-siteicon-192x192.png" sizes="192x192" />
# <link rel="apple-touch-icon" href="https://athleticinterest.com/wp-content/uploads/cropped-siteicon-180x180.png" />
# <meta name="msapplication-TileImage" content="https://athleticinterest.com/wp-content/uploads/cropped-siteicon-270x270.png" />
#
#
# 		<!--[if lt IE 9]>
# 			<link href="https://athleticinterest.com/wp-content/themes/athleticinterest2022/css/ie.css" rel="stylesheet">
# 			<script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7/html5shiv.min.js"></script>
# 			<script src="https://cdnjs.cloudflare.com/ajax/libs/selectivizr/1.0.2/selectivizr-min.js"></script>
# 		<![endif]-->
#
# 	</head>
# 	<body data-rsssl=1 class="home page-template page-template-templates page-template-startseite page-template-templatesstartseite-php page page-id-2 top-parent-2">
#
#
#
# 			<header class="header clear" role="banner" id="headroom">
# 					<div class="wrapper">
#
# 						<div class="logo">
# 							<a href="https://athleticinterest.com">
# 								<img src="https://athleticinterest.com/wp-content/themes/athleticinterest2022/img/logo.svg" alt="Logo" class="logo-img">
# 							</a>
# 						</div>
#
#
# 						<div class="mobile-toggle" id="mobile-toggle">
# 							<div class="burger">
# 							 <div class="burg a"></div>
# 							 <div class="burg b"></div>
# 							 <div class="burg c"></div>
# 							</div>
# 						</div>
#
# 				</div>
#
# 				<div class="menu-container">
# 					<div class="wrapper">
# 						<div class="menu-container-inner">
# 							<div class="menu-logo">
# 								<img src="https://athleticinterest.com/wp-content/themes/athleticinterest2022/img/menu-logo.svg" alt="Athletic Interest">
# 							</div>
# 							<nav class="nav" role="navigation">
#
# 																        <ul><li id="menu-item-27" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home current-menu-item page_item page-item-2 current_page_item menu-item-27"><a href="https://athleticinterest.com/" aria-current="page">Start</a></li>
# <li id="menu-item-25" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-25"><a href="https://athleticinterest.com/contact/">Contact + FAQ</a></li>
# <li id="menu-item-348" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-348"><a href="https://athleticinterest.com/about/">About</a></li>
# </ul>															</nav>
# 						</div>
# 					</div>
# 				</div>
# 			</header>
#
#
# <main class="main-site-sections">
#
#
#
#
#
#           <!-- ////////////////////    Start Video BG  ////////////// -->
#       <section class="section section-start-textvideobg">
#   <div class="wrapper">
#     <div class="modul modul-textvideo">
#       <div class="videooverlay">
#                 <img src="https://athleticinterest.com/wp-content/uploads/subtract-1.svg" alt="" />
#       </div>
#                         <video playsinline autoplay loop muted preload poster="https://athleticinterest.com/wp-content/uploads/test-0001.jpg">
#         <source src="https://athleticinterest.com/wp-content/uploads/athletic-loop.webm" type='video/webm' />
#         <source src="https://athleticinterest.com/wp-content/uploads/athletic-loop.mp4" type='video/mp4' />
#       </video>
#     </div>
#           <h2>
#         THE MODERN SPORTS MEDIA COMPANY      </h2>
#       </div>
# </section>
#
#
#
#
#           <!-- ////////////////////    Video player  ////////////// -->
#       <section class="section section-start-video">
#   <div class="wrapper">
#     <div class="modul modul-video">
#       <div class="bg-logo rellax" data-rellax-speed="1.5">
#         <svg fill="none" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 397 892">
#           <g clip-path="url(#a)" fill="#fff">
#             <path d="M396.14 499.3h-.19c0-117.37 0-275.28.01-297.65.01-17.55-1.67-34.91-5.98-51.93C365.05 51.2 268.77-12.28 168.6 2 81.56 14.41.39 93.68.18 196.28.11 232.51.02 589.98 0 626.21h.16c.03 32.69.07 60.68.11 67.89.32 52.15 18.87 97.2 54.68 135.04 57.91 61.17 147.92 80.67 223.62 44.25 75.37-36.25 115.72-97.89 117.25-183.18.31-17.37.35-173.55.31-190.92l.01.01ZM250.99 835.85C150.95 870.8 63.22 804.42 47.64 722.03c-2.18-11.53-2.87-23.47-2.99-35.24-.06-5.98-.1-30.81-.13-60.58h.31c-.07-37.64-.69-396.54.18-434.16 1.76-76.64 65.05-141.11 141-146.73 80.07-5.91 136.93 48.47 156.26 100.77 6.67 18.07 9.22 36.78 9.22 55.95 0 22.28-.06 179.98-.12 297.25h-.05c.01 3.34.02 12.25.04 24.5-.03 51.81-.05 91.97-.07 102.41h.2c.05 30.28.1 55.65.17 61.84.85 79.72-53.12 131.19-100.66 147.8l-.01.01Z"/>
#             <path d="M331.74 499.3h-.05c0-117.07 0-274.39.05-296.47.03-15-1.43-29.8-6-44.1-19.79-61.86-78.93-100.27-143.1-93.05-67.7 7.61-118.96 64.58-119.2 133.15-.13 35.38-.14 392-.13 427.38h.07v62.71c0 19.04 2.77 37.63 10.37 55.15 26.01 59.92 87.42 92.13 151.17 79.55 59.15-11.68 105.32-66.24 106.47-127.1.14-7.64.24-36.68.3-70.31h.02v-10.56c.07-49.68.07-105.31.04-116.35h-.01Zm-44.21 189.19c.33 51.53-37.58 83.42-69.42 90.81-52.93 12.27-106.45-27.74-109.17-82.39-.11-2.22-.32-4.45-.32-6.67v-64.03h.25c-.07-36.83-.62-394.91.22-431.7.78-34.82 25.17-67.27 57.39-79.19 34.38-12.71 71.18-4.04 96.03 22.37 16.87 17.93 24.95 39.18 24.93 63.8-.02 22.41-.05 180.4-.09 297.81h-.01c0 1.59 0 4.44.01 8.3-.02 59.48-.03 107.06-.04 118.61h.14c.03 30.46.06 56.02.1 62.28h-.02Z"/>
#           </g>
#           <defs>
#             <clipPath id="a">
#               <path fill="#fff" d="M0 0h396.15v891.71H0z"/>
#             </clipPath>
#           </defs>
#         </svg>
#       </div>
#       <a class="video-wrapper popup-youtube" href="https://www.youtube.com/watch?v=mcs51kMoqEw">
#
#                                         <video playsinline autoplay loop muted  preload  poster="https://athleticinterest.com/wp-content/uploads/loop.jpg">
#             <source src="https://athleticinterest.com/wp-content/uploads/loop2.webm" type='video/webm' />
#             <source src="https://athleticinterest.com/wp-content/uploads/loop2.mp4" type='video/mp4' />
#           </video>
#           <div class="play-button">
#             <svg fill="none" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 200 200">
#               <circle cx="100" cy="100" r="92" stroke="#EE573C" stroke-width="16"/>
#               <path d="m144 100-66.75 44.167V55.833L144 100Z" fill="#EE573C"/>
#             </svg>
#           </div>
#       </a>
#       <div class="container">
#         <div class="video-text">
#           <p>WE CREATE BEAUTIFUL <strong>VIDEO ESSAYS</strong> ABOUT THE <strong>ICONIC</strong> <strong>BRANDS</strong>, <strong>CREATIVE</strong> <strong>MINDS</strong> AND <strong>COMPETITIVE</strong> <strong>ETHOS </strong>OF<strong> SPORTS</strong>.</p>
#         </div>
#       </div>
#     </div>
#   </div>
# </section>
#
#
#
#
#           <!-- ////////////////////    Best Of  ////////////// -->
#       <section class="section section-start-bestof">
#   <div class="section-start-bestof--title">
#   <div class="inner">
#     <span>Best Of</span>
#   </div>
# </div>
#   <div class="wrapper">
#
#
#
#
#         <div class="bestof-item">
#           <div class="bestof-item--left">
#                                           <div class="media-item youtube">
#   <div class="inner">
#           <div class="media-item--img">
#         <div class="img-wrapper">
#                     <img  srcset="https://athleticinterest.com/wp-content/uploads/thumbnail-how-red-bull-makes-money.png 1500w,
#                               https://athleticinterest.com/wp-content/uploads/thumbnail-how-red-bull-makes-money-1000x563.png 1000w,
#                               https://athleticinterest.com/wp-content/uploads/thumbnail-how-red-bull-makes-money-500x281.png 500w,
#                               https://athleticinterest.com/wp-content/uploads/thumbnail-how-red-bull-makes-money-250x141.png 250w"
#                     sizes="(min-width: 56em) 550px, 100vw"
#                     src="https://athleticinterest.com/wp-content/uploads/thumbnail-how-red-bull-makes-money-1000x563.png"
#                     alt="" itemprob="image">
#         </div>
#       </div>
#
#     <div class="media-item--textbox">
#
#               <div class="text">
#           How Red Bull Makes Money        </div>
#                     <div class="likes">
#           <span>6.687.707 views</span>
#         </div>
#           </div>
#           <div class="media-item-link">
#         <a href="https://www.youtube.com/watch?v=Xast5FpOf3E" class="btn pill" target="_blank">
#           <span>watch</span>
#         </a>
#       </div>
#
#   </div>
# </div>Â
#                                     </div>
#           <div class="bestof-item--devider rellax" data-rellax-speed="-1.9" data-rellax-percentage="0.5">
#             <span>Best Of</span>
#           </div>
#           <div class="bestof-item--right rellax" data-rellax-speed="1.5">
#                                           <div class="media-item youtube">
#   <div class="inner">
#           <div class="media-item--img">
#         <div class="img-wrapper">
#                     <img  srcset="https://athleticinterest.com/wp-content/uploads/thumbnail-shirt-4-expensive-shirts-v4-1.png 1500w,
#                               https://athleticinterest.com/wp-content/uploads/thumbnail-shirt-4-expensive-shirts-v4-1-1000x563.png 1000w,
#                               https://athleticinterest.com/wp-content/uploads/thumbnail-shirt-4-expensive-shirts-v4-1-500x281.png 500w,
#                               https://athleticinterest.com/wp-content/uploads/thumbnail-shirt-4-expensive-shirts-v4-1-250x141.png 250w"
#                     sizes="(min-width: 56em) 550px, 100vw"
#                     src="https://athleticinterest.com/wp-content/uploads/thumbnail-shirt-4-expensive-shirts-v4-1-1000x563.png"
#                     alt="" itemprob="image">
#         </div>
#       </div>
#
#     <div class="media-item--textbox">
#
#               <div class="text">
#           Why Are Football Shirts So Expensive?        </div>
#                     <div class="likes">
#           <span>789.626 views</span>
#         </div>
#           </div>
#           <div class="media-item-link">
#         <a href="https://www.youtube.com/watch?v=Xast5FpOf3E" class="btn pill" target="_blank">
#           <span>watch</span>
#         </a>
#       </div>
#
#   </div>
# </div>Â
#                                     </div>
#         </div>
#
#
#         <div class="bestof-item">
#           <div class="bestof-item--left">
#                                           <div class="media-item instagram">
#   <div class="inner">
#           <div class="media-item--img">
#         <div class="img-wrapper">
#                     <img  srcset="https://athleticinterest.com/wp-content/uploads/insta.png 1500w,
#                               https://athleticinterest.com/wp-content/uploads/insta.png 1000w,
#                               https://athleticinterest.com/wp-content/uploads/insta-500x743.png 500w,
#                               https://athleticinterest.com/wp-content/uploads/insta-250x371.png 250w"
#                     sizes="(min-width: 56em) 550px, 100vw"
#                     src="https://athleticinterest.com/wp-content/uploads/insta.png"
#                     alt="" itemprob="image">
#         </div>
#       </div>
#
#     <div class="media-item--textbox">
#               <div class="likes">
#           <span>12.228 likes</span>
#         </div>
#                     <div class="text">
#           <span class="username">athleticinterest</span> Emma Raducanu is a favourite among sponsors.        </div>
#           </div>
#           <div class="media-item-link">
#         <a href="https://www.instagram.com/p/CfZNlV4oUhp/" class="btn pill" target="_blank">
#           <span>Show on insta</span>
#         </a>
#       </div>
#
#   </div>
# </div>Â
#                                     </div>
#           <div class="bestof-item--devider rellax" data-rellax-speed="-1.9" data-rellax-percentage="0.5">
#             <span>Best Of</span>
#           </div>
#           <div class="bestof-item--right rellax" data-rellax-speed="1.5">
#                                           <div class="media-item instagram">
#   <div class="inner">
#           <div class="media-item--img">
#         <div class="img-wrapper">
#                     <img  srcset="https://athleticinterest.com/wp-content/uploads/img-fa06d5291875-1.jpeg 1500w,
#                               https://athleticinterest.com/wp-content/uploads/img-fa06d5291875-1.jpeg 1000w,
#                               https://athleticinterest.com/wp-content/uploads/img-fa06d5291875-1-500x744.jpeg 500w,
#                               https://athleticinterest.com/wp-content/uploads/img-fa06d5291875-1-250x372.jpeg 250w"
#                     sizes="(min-width: 56em) 550px, 100vw"
#                     src="https://athleticinterest.com/wp-content/uploads/img-fa06d5291875-1.jpeg"
#                     alt="" itemprob="image">
#         </div>
#       </div>
#
#     <div class="media-item--textbox">
#               <div class="likes">
#           <span>73.473 likes</span>
#         </div>
#                     <div class="text">
#           <span class="username">athleticinterest</span> Is this the greatest investment Lebron James ever made?        </div>
#           </div>
#           <div class="media-item-link">
#         <a href="https://www.instagram.com/p/CfZNlV4oUhp/" class="btn pill" target="_blank">
#           <span>Show on insta</span>
#         </a>
#       </div>
#
#   </div>
# </div>Â
#                                     </div>
#         </div>
#
#
#         <div class="bestof-item">
#           <div class="bestof-item--left">
#                                           <div class="media-item youtube">
#   <div class="inner">
#           <div class="media-item--img">
#         <div class="img-wrapper">
#                     <img  srcset="https://athleticinterest.com/wp-content/uploads/thumbnail-lebron.png 1500w,
#                               https://athleticinterest.com/wp-content/uploads/thumbnail-lebron-1000x563.png 1000w,
#                               https://athleticinterest.com/wp-content/uploads/thumbnail-lebron-500x281.png 500w,
#                               https://athleticinterest.com/wp-content/uploads/thumbnail-lebron-250x141.png 250w"
#                     sizes="(min-width: 56em) 550px, 100vw"
#                     src="https://athleticinterest.com/wp-content/uploads/thumbnail-lebron-1000x563.png"
#                     alt="" itemprob="image">
#         </div>
#       </div>
#
#     <div class="media-item--textbox">
#
#               <div class="text">
#           How LeBron Bought Liverpool FC (2%)        </div>
#                     <div class="likes">
#           <span>595.252 views</span>
#         </div>
#           </div>
#           <div class="media-item-link">
#         <a href="https://youtu.be/aHBnSvSDmQ8" class="btn pill" target="_blank">
#           <span>watch</span>
#         </a>
#       </div>
#
#   </div>
# </div>Â
#                                     </div>
#           <div class="bestof-item--devider rellax" data-rellax-speed="-1.9" data-rellax-percentage="0.5">
#             <span>Best Of</span>
#           </div>
#           <div class="bestof-item--right rellax" data-rellax-speed="1.5">
#                                           <div class="media-item youtube">
#   <div class="inner">
#           <div class="media-item--img">
#         <div class="img-wrapper">
#                     <img  srcset="https://athleticinterest.com/wp-content/uploads/ronaldihno-thumbnail-v2.png 1500w,
#                               https://athleticinterest.com/wp-content/uploads/ronaldihno-thumbnail-v2-1000x563.png 1000w,
#                               https://athleticinterest.com/wp-content/uploads/ronaldihno-thumbnail-v2-500x281.png 500w,
#                               https://athleticinterest.com/wp-content/uploads/ronaldihno-thumbnail-v2-250x141.png 250w"
#                     sizes="(min-width: 56em) 550px, 100vw"
#                     src="https://athleticinterest.com/wp-content/uploads/ronaldihno-thumbnail-v2-1000x563.png"
#                     alt="" itemprob="image">
#         </div>
#       </div>
#
#     <div class="media-item--textbox">
#
#               <div class="text">
#           How A Fake Ronaldinho Video Changed YouTube        </div>
#                     <div class="likes">
#           <span>241.176 views</span>
#         </div>
#           </div>
#           <div class="media-item-link">
#         <a href="https://youtu.be/oMaqjcC3wiE" class="btn pill" target="_blank">
#           <span>watch</span>
#         </a>
#       </div>
#
#   </div>
# </div>Â
#                                     </div>
#         </div>
#
#
#
#   </div>
#   <div class="bg">
#     <div class="headline">
#       <span>Best Of</span>
#     </div>
#   </div>
# </section>
#
#
#
#
#           <!-- ////////////////////   feedback  ////////////// -->
#       <section class="section section-start-feedback">
#       <div class="wrapper">
#       <div class="section-title">
#         <h3>Feedback</h3>
#       </div>
#     </div>
#
#   <div class="wrapper card-stack-container">
#     <div class="card-stack">
#     				<a class="buttons prev" href="#"><</a>
#     				<ul class="card-list">
#
#                   <li class="card">
#                     <div class="card-inner">
#                       <div class="card-thumb">
#                         <div class="img-wrapper">
#                                                     <img src="https://athleticinterest.com/wp-content/uploads/sarvesh.jpg" alt="" />
#                         </div>
#                       </div>
#                       <div class="card-content">
#                         <div class="card-content--header">
#                           <span class="username"> Sarvesh K</span><span class="plattform">YouTube</span>
#                         </div>
#                         <div class="card-content--text">
#                           <blockquote>
#                             How on earth is this content free?                          </blockquote>
#                         </div>
#                         <div class="card-content--footer">
#                           <img src="https://athleticinterest.com/wp-content/themes/athleticinterest2022/img/card-icons.svg" alt="Icons">
#                         </div>
#                       </div>
#                     </div>
#                   </li>
#
#
#                   <li class="card">
#                     <div class="card-inner">
#                       <div class="card-thumb">
#                         <div class="img-wrapper">
#                                                     <img src="https://athleticinterest.com/wp-content/uploads/akairo.jpg" alt="" />
#                         </div>
#                       </div>
#                       <div class="card-content">
#                         <div class="card-content--header">
#                           <span class="username"> Akairo Hoshi</span><span class="plattform">YouTube</span>
#                         </div>
#                         <div class="card-content--text">
#                           <blockquote>
#                             This isn't editing, this is art.                          </blockquote>
#                         </div>
#                         <div class="card-content--footer">
#                           <img src="https://athleticinterest.com/wp-content/themes/athleticinterest2022/img/card-icons.svg" alt="Icons">
#                         </div>
#                       </div>
#                     </div>
#                   </li>
#
#
#                   <li class="card">
#                     <div class="card-inner">
#                       <div class="card-thumb">
#                         <div class="img-wrapper">
#                                                     <img src="https://athleticinterest.com/wp-content/uploads/sbabu.jpg" alt="" />
#                         </div>
#                       </div>
#                       <div class="card-content">
#                         <div class="card-content--header">
#                           <span class="username">S Babu</span><span class="plattform">YouTube</span>
#                         </div>
#                         <div class="card-content--text">
#                           <blockquote>
#                             For an MBA student, this is f*cking awesome. Thank you!                          </blockquote>
#                         </div>
#                         <div class="card-content--footer">
#                           <img src="https://athleticinterest.com/wp-content/themes/athleticinterest2022/img/card-icons.svg" alt="Icons">
#                         </div>
#                       </div>
#                     </div>
#                   </li>
#
#
#                   <li class="card">
#                     <div class="card-inner">
#                       <div class="card-thumb">
#                         <div class="img-wrapper">
#                                                     <img src="https://athleticinterest.com/wp-content/uploads/adeola.jpg" alt="" />
#                         </div>
#                       </div>
#                       <div class="card-content">
#                         <div class="card-content--header">
#                           <span class="username">Adeola</span><span class="plattform">YouTube</span>
#                         </div>
#                         <div class="card-content--text">
#                           <blockquote>
#                             Wow! What on earth is this channel? The Vox of football! Keep up the production, cheers.                          </blockquote>
#                         </div>
#                         <div class="card-content--footer">
#                           <img src="https://athleticinterest.com/wp-content/themes/athleticinterest2022/img/card-icons.svg" alt="Icons">
#                         </div>
#                       </div>
#                     </div>
#                   </li>
#
#
#                   <li class="card">
#                     <div class="card-inner">
#                       <div class="card-thumb">
#                         <div class="img-wrapper">
#                                                     <img src="https://athleticinterest.com/wp-content/uploads/toto.jpg" alt="" />
#                         </div>
#                       </div>
#                       <div class="card-content">
#                         <div class="card-content--header">
#                           <span class="username">Thomas W</span><span class="plattform">YouTube</span>
#                         </div>
#                         <div class="card-content--text">
#                           <blockquote>
#                             This channel is basically National Geographic, Discovery channel and History channel all in one but about sports.                          </blockquote>
#                         </div>
#                         <div class="card-content--footer">
#                           <img src="https://athleticinterest.com/wp-content/themes/athleticinterest2022/img/card-icons.svg" alt="Icons">
#                         </div>
#                       </div>
#                     </div>
#                   </li>
#
#
#                   <li class="card">
#                     <div class="card-inner">
#                       <div class="card-thumb">
#                         <div class="img-wrapper">
#                                                     <img src="https://athleticinterest.com/wp-content/uploads/channels4-profile.jpg" alt="" />
#                         </div>
#                       </div>
#                       <div class="card-content">
#                         <div class="card-content--header">
#                           <span class="username">Asian Food Nerd</span><span class="plattform">YouTube</span>
#                         </div>
#                         <div class="card-content--text">
#                           <blockquote>
#                             ðŸŽ¥ You are the MBA Sports Marketing Professor we always wanted âš½                          </blockquote>
#                         </div>
#                         <div class="card-content--footer">
#                           <img src="https://athleticinterest.com/wp-content/themes/athleticinterest2022/img/card-icons.svg" alt="Icons">
#                         </div>
#                       </div>
#                     </div>
#                   </li>
#
#               	                  			</ul>
#     			<a class="buttons next" href="#">></a>
#   	</div>
#   </div>
# </section>
#
#
#
#
#           <!-- ////////////////////   Numbers  ////////////// -->
#       <section class="section section-start-numbers">
#   <div class="wrapper">
#           <div class="numbers-item number-views" id="start1">
#         <div class="numbers-item--number">
#           <div class="numbers-item--icon">
#             <svg fill="none" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 66 67">
#   <path fill-rule="evenodd" clip-rule="evenodd" d="M15.99 3h33.981V0h-33.98v3ZM6.282 15.136h53.4v-3H6.28v3ZM63 27.052H3v36h60v-36Zm-63-3v42h66v-42H0Zm45.975 21.035L24.5 32.427v25.072l21.475-12.412ZM27.5 52.3V37.678l12.525 7.383-12.525 7.24Z" fill="#fff"/>
# </svg>
#           </div>
#           <div class="numbers-item--text">
#                         <div id="counter1" class="number-count" data-counnumer="50385088"></div>
#           </div>
#         </div>
#         <div class="numbers-item--description">
#           Views
#         </div>
#       </div>
#       </div>
#   <div class="wrapper">
#           <div class="section-title">
#         <h3>
#           AI in<br />
# numbers        </h3>
#       </div>
#
#           <div class="numbers-item number-subscriber">
#         <div class="numbers-item--number">
#           <div class="numbers-item--icon">
#             <svg fill="none" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 80 80">
#   <path d="M68.3 63.91h-.01m0 0c.63 1.03-.08 2.38-1.26 2.38H13.45c-1.17 0-1.89-1.35-1.26-2.38l6.16-10.11c.9-1.47 1.38-3.16 1.39-4.9.03-3.68.07-10.94.07-20.04C19.81 15.53 34.68 14 34.68 14h.34V8.93c0-3 2.34-5.43 5.23-5.43 2.89 0 5.23 2.43 5.23 5.43L45.5 14h.32S60.5 15.88 60.5 28.75c0 8.93.13 16.44.21 20.21.04 1.69.52 3.34 1.39 4.77l6.19 10.18Z" stroke="#fff" stroke-width="3" stroke-miterlimit="10"/>
#   <path d="M34.18 72.57c0 3 2.72 5.43 6.07 5.43s6.07-2.43 6.07-5.43v-1.5l-12.15-.05v1.56l.01-.01Z" fill="#fff"/>
#   <path d="M9.5 36.82c0-14.37 4.2-23.18 14.87-27.86M70.5 36.82c0-14.37-4.2-23.18-14.87-27.86" stroke="#fff" stroke-width="3" stroke-miterlimit="10" stroke-linecap="round"/>
# </svg>
#           </div>
#           <div class="numbers-item--text">
#
#             <span id="counter2" class="number-count" data-counnumer="565000"></span>
#           </div>
#         </div>
#         <div class="numbers-item--description">
#           Subscribers
#         </div>
#       </div>
#
#   </div>
#   <div class="wrapper">
#           <div class="numbers-item number-average">
#         <div class="numbers-item--number">
#           <div class="numbers-item--icon">
#             <svg fill="none" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 66 67">
#   <path fill-rule="evenodd" clip-rule="evenodd" d="M15.99 3h33.981V0h-33.98v3ZM6.282 15.136h53.4v-3H6.28v3ZM63 27.052H3v36h60v-36Zm-63-3v42h66v-42H0Zm45.975 21.035L24.5 32.427v25.072l21.475-12.412ZM27.5 52.3V37.678l12.525 7.383-12.525 7.24Z" fill="#fff"/>
# </svg>
#           </div>
#           <div class="numbers-item--text">
#             <span id="counter3" class="number-count" data-counnumer="740957.17647059"></span>
#           </div>
#         </div>
#         <div class="numbers-item--description">
#           Average Views
#         </div>
#       </div>
#
#   </div>
#   <div class="wrapper">
#     <div class="numbers-devider">
#       <svg fill="none" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 319 61">
#   <path fill="#fff" d="M.934 44.257 315.839 0l.557 3.961L1.491 48.218zM2.604 56.14l314.905-44.257.557 3.961L3.16 60.101z"/>
# </svg>
#     </div>
#   </div>
#   <div class="wrapper">
#     <div class="numbers-stadion">
#       <div class="numbers-stadion--text">
#                   <p>this is<br />
# <strong class="big">7x</strong><br />
# <strong>camp nou</strong><br />
# watching<br />
# every video</p>
#               </div>
#               <div class="numbers-stadion--img">
#                     <img src="https://athleticinterest.com/wp-content/uploads/image-4.svg" alt="" />
#         </div>
#           </div>
#   </div>
# </section>
#
#
#
#
#           <!-- ////////////////////  Known From  ////////////// -->
#       <section class="section section-start-known">
#   <div class="wrapper">
#     <div class="start-known-container">
#       <div class="start-known-column column-1 rellax" data-rellax-speed="-0.9"  data-rellax-percentage="0.5">
#                               <div class="know-item-wrapper">
#               <div class="inner">
#                 <div class="known-item">
#                   <div class="inner">
#                     <a class="icon" href="https://www.youtube.com/watch?v=iWt2__3XXCw">
#                                             <img src="https://athleticinterest.com/wp-content/uploads/bl-logo-rgb-pos.png" alt="" />
#                     </a>
#                   </div>
#                 </div>
#               </div>
#             </div>
#                         </div>
#       <div class="start-known-column column-2 rellax" data-rellax-speed="1.5"  data-rellax-percentage="0.5">
#                               <div class="know-item-wrapper">
#               <div class="inner">
#                 <div class="known-item">
#                   <div class="inner">
#                     <a class="icon" href="https://www.youtube.com/watch?v=1fsHd2Wo0AI">
#                                             <img src="https://athleticinterest.com/wp-content/uploads/onefootball-symbol-rgb-black.png" alt="" />
#                     </a>
#                   </div>
#                 </div>
#               </div>
#             </div>
#                       <div class="know-item-wrapper">
#               <div class="inner">
#                 <div class="known-item">
#                   <div class="inner">
#                     <a class="icon" href="https://www.youtube.com/watch?v=jGP-Czw3ymQ">
#                                             <img src="https://athleticinterest.com/wp-content/uploads/pv-sports-avatar-v2-1.png" alt="" />
#                     </a>
#                   </div>
#                 </div>
#               </div>
#             </div>
#                         </div>
#       <div class="start-known-devider rellax" data-rellax-speed="-1.5"  data-rellax-percentage="0.5">
#                   <span>
#             known from          </span>
#               </div>
#       <div class="start-known-column column-3 rellax" data-rellax-speed="-0.9"  data-rellax-percentage="0.5">
#
#
#                     	              <div class="know-item-wrapper">
#                 <div class="inner">
#                   <div class="known-item">
#                     <div class="inner">
#                       <a class="icon" href="https://www.youtube.com/channel/UCddYvBABZ8J47nJxj-69RRw">
#                                                 <img src="https://athleticinterest.com/wp-content/uploads/yt-logo-rgb-light.png" alt="" />
#                       </a>
#                     </div>
#                   </div>
#                 </div>
#               </div>
#
#
#       </div>
#     </div>
#   </div>
# </section>
#
#
#
#
#           <!-- ////////////////////  Newsletter  ////////////// -->
#       <section class="section section-start-newsletter">
#   <div class="wrapper title-wrapper">
#           <div class="newsletter-title">
#         <h3>stay<br />
# curious</h3>
#       </div>
#             <div class="newsletter-description">
#         <small>subscribe to<br />
# our newsletter</small>
#       </div>
#       </div>
#   <div class="wrapper">
#     <div class="newsletter-marquee">
#       <div class="marquee">
#         <ul class="marquee__content">
#                     	              <li>weekly updates</li>
#           	              <li>the business of sports</li>
#           	              <li>brand new video content</li>
#           	              <li>big next steps</li>
#           	              <li>thrilling announcements</li>
#           	                  </ul>
#         <!-- Mirrors the content above -->
#         <ul class="marquee__content" aria-hidden="true">
#                     	              <li>weekly updates</li>
#           	              <li>the business of sports</li>
#           	              <li>brand new video content</li>
#           	              <li>big next steps</li>
#           	              <li>thrilling announcements</li>
#           	                  </ul>
#       </div>
#     </div>
#   </div>
#   <div class="wrapper">
#
#           <div class="newsletterbox">
#             <div class="newsletterbox-inner">
#               <div class="inner">
#                 <div id="custom-substack-embed"></div>
#               </div>
#             </div>
#           </div>
#
#   </div>
# </section>
#
#
#
#
#
#
#
# </main>
#
# 			<!-- footer -->
# 			<footer class="footer" role="contentinfo">
# 				<div class="wrapper">
# 					<div class="footer-social">
# 						<div class="social-title">
# 							<span>the fields<br />
# where we play</span>
# 						</div>
# 						<div class="social-icons">
# 																<ul>
# 																			<li>
# 																							<a  href="https://www.youtube.com/c/athleticinterest" target="_blank">
# 																										<img src="https://athleticinterest.com/wp-content/uploads/youtube-logo.svg" alt="" />
# 												</a>
# 																					</li>
# 																			<li>
# 																							<a  href="https://www.instagram.com/athleticinterest/?hl=de" target="_blank">
# 																										<img src="https://athleticinterest.com/wp-content/uploads/instagram-logo.svg" alt="" />
# 												</a>
# 																					</li>
# 																			<li>
# 																							<a  href="https://www.tiktok.com/@athleticinterest" target="_blank">
# 																										<img src="https://athleticinterest.com/wp-content/uploads/tiktok-logo.svg" alt="" />
# 												</a>
# 																					</li>
# 																			<li>
# 																							<a  href="mailto:hello@athleticinterest.com" target="_blank">
# 																										<img src="https://athleticinterest.com/wp-content/uploads/mail-logo.svg" alt="" />
# 												</a>
# 																					</li>
# 																		</ul>
# 													</div>
# 					</div>
# 					<div class="footer-contact">
# 															<a  href="https://athleticinterest.com/contact/" target="_self">Let&#039;s work together</a>
# 												</div>
# 				</div>
# 				<div class="container">
# 					<div class="footer-copy">
# 						<small>&copy; 2022 Athletic Interest</small>
# 					</div>
# 					<div class="footer-meta">
# 						<nav>
# 																		<ul><li id="menu-item-254" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-254"><a href="https://athleticinterest.com/imprint/">Imprint</a></li>
# <li id="menu-item-253" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-privacy-policy menu-item-253"><a href="https://athleticinterest.com/privacy/">Privacy Policy</a></li>
# </ul>													</nav>
# 					</div>
# 				</div>
#
#
#
#
# 			</footer>
# 			<!-- /footer -->
#
#
#
# 		<!--googleoff: all--><div data-nosnippet><script id="BorlabsCookieBoxWrap" type="text/template"><div
#     id="BorlabsCookieBox"
#     class="BorlabsCookie"
#     role="dialog"
#     aria-labelledby="CookieBoxTextHeadline"
#     aria-describedby="CookieBoxTextDescription"
#     aria-modal="true"
# >
#     <div class="bottom-center" style="display: none;">
#         <div class="_brlbs-bar-wrap">
#             <div class="_brlbs-bar _brlbs-bar-advanced">
#                 <div class="cookie-box">
#                     <div class="container">
#                         <div class="row align-items-center">
#                             <div class="col-12 col-sm-9">
#                                 <div class="row">
#                                     <div class="col-12">
#                                         <div class="_brlbs-flex-left">
#                                                                                         <span role="heading" aria-level="3" class="_brlbs-h3" id="CookieBoxTextHeadline">
#                                                 Privacy Preference                                            </span>
#                                         </div>
#
#                                         <p id="CookieBoxTextDescription">
# ...
#                                                         <th>Name</th>
#                                                         <td>
#                                                             <label>
#                                                                 Twitter                                                            </label>
#                                                         </td>
#                                                     </tr>
#
#                                                     <tr>
#                                                         <th>Provider</th>
#                                                         <td>Twitter International Company, One Cumberland Place, Fenian Street, Dublin 2, D02 AX07, Ireland</td>
#                                                     </tr>
#
#                                                                                                             <tr>
#                                                             <th>Purpose</th>
#                                                             <td>Used to unblock Twitter content.</td>
#                                                         </tr>
#
#                                                                                                             <tr>
#                                                             <th>Privacy Policy</th>
#                                                             <td class="_brlbs-pp-url">
#                                                                 <a
#                                                                     href="https://twitter.com/privacy"
#                                                                     target="_blank"
#                                                                     rel="nofollow noopener noreferrer"
#                                                                 >
#                                                                     https://twitter.com/privacy                                                                </a>
#                                                             </td>
#                                                         </tr>
#
#                                                                                                             <tr>
#                                                             <th>Host(s)</th>
#                                                             <td>.twimg.com, .twitter.com</td>
#                                                         </tr>
#
#                                                                                                             <tr>
#                                                             <th>Cookie Name</th>
#                                                             <td>__widgetsettings, local_storage_support_test</td>
#                                                         </tr>
#
#                                                                                                             <tr>
#                                                             <th>Cookie Expiry</th>
#                                                             <td>Unlimited</td>
#                                                         </tr>
#                                                                                                         </table>
#                                                                                                 <table>
#                                                                                                             <tr>
#                                                             <th>Accept</th>
#                                                             <td>
#                                                                 <label class="_brlbs-btn-switch _brlbs-btn-switch--textRight">
#                                                                     <span class="sr-only">YouTube</span>
#                                                                     <input
#                                                                         id="borlabs-cookie-youtube"
#                                                                         tabindex="0"
#                                                                         type="checkbox" data-cookie-group="external-media"
#                                                                         name="cookies[external-media][]"
#                                                                         value="youtube"
#                                                                          checked                                                                        data-borlabs-cookie-switch
#                                                                     />
#
#                                                                     <span class="_brlbs-slider"></span>
#
#                                                                     <span
#                                                                         class="_brlbs-btn-switch-status"
#                                                                         data-active="On"
#                                                                         data-inactive="Off"
#                                                                         aria-hidden="true">
#                                                                     </span>
#                                                                 </label>
#                                                             </td>
#                                                         </tr>
#
#                                                     <tr>
#                                                         <th>Name</th>
#                                                         <td>
#                                                             <label>
#                                                                 YouTube                                                            </label>
#                                                         </td>
#                                                     </tr>
#
#                                                     <tr>
#                                                         <th>Provider</th>
#                                                         <td>Google Ireland Limited, Gordon House, Barrow Street, Dublin 4, Ireland</td>
#                                                     </tr>
#
#                                                                                                             <tr>
#                                                             <th>Purpose</th>
#                                                             <td>Used to unblock YouTube content.</td>
#                                                         </tr>
#
#                                                                                                             <tr>
#                                                             <th>Privacy Policy</th>
#                                                             <td class="_brlbs-pp-url">
#                                                                 <a
#                                                                     href="https://policies.google.com/privacy?hl=en&#038;gl=en"
#                                                                     target="_blank"
#                                                                     rel="nofollow noopener noreferrer"
#                                                                 >
#                                                                     https://policies.google.com/privacy?hl=en&#038;gl=en                                                                </a>
#                                                             </td>
#                                                         </tr>
#
#                                                                                                             <tr>
#                                                             <th>Host(s)</th>
#                                                             <td>google.com</td>
#                                                         </tr>
#
#                                                                                                             <tr>
#                                                             <th>Cookie Name</th>
#                                                             <td>NID</td>
#                                                         </tr>
#
#                                                                                                             <tr>
#                                                             <th>Cookie Expiry</th>
#                                                             <td>6 Month</td>
#                                                         </tr>
#                                                                                                         </table>
#                                                                                         </div>
#                                     </div>
#                                                                                                 </fieldset>
#                                         </div>
#
#                 <div class="d-flex justify-content-between">
#                     <p class="_brlbs-branding flex-fill">
#                                             </p>
#
#                     <p class="_brlbs-legal flex-fill">
#                                                     <a href="https://athleticinterest.ps-kundenserver.de/privacy/">
#                                 Privacy Policy                            </a>
#
#                                                     <span class="_brlbs-separator"></span>
#
#                                                     <a href="https://athleticinterest.ps-kundenserver.de/imprint/">
#                                 Imprint                            </a>
#                                                 </p>
#                 </div>
#             </div>
#         </div>
#     </div>
# </div>
#             </div>
#         </div>
#     </div>
# </div>
# </script></div><!--googleon: all--><script type='text/javascript' src='https://athleticinterest.com/wp-content/themes/athleticinterest2022/js/min/plugins-min.js' id='plugins-js'></script>
# <script type='text/javascript' src='https://athleticinterest.com/wp-content/themes/athleticinterest2022/js/lib/video.min.js' id='video-js'></script>
# <script type="module" src="https://athleticinterest.com/wp-content/themes/athleticinterest2022/js/lib/countUp.min.js"></script><script type="module" src="https://athleticinterest.com/wp-content/themes/athleticinterest2022/js/counter.js"></script><script type='text/javascript' src='https://athleticinterest.com/wp-content/themes/athleticinterest2022/js/lib/headroom.min.js' id='headroom-js'></script>
# <script type='text/javascript' src='https://athleticinterest.com/wp-content/themes/athleticinterest2022/js/substack.js' id='substack-js'></script>
# <script type='text/javascript' src='https://athleticinterest.com/wp-content/themes/athleticinterest2022/js/widget.js' id='widget-js'></script>
# <script type='text/javascript' src='https://athleticinterest.com/wp-content/themes/athleticinterest2022/js/min/scripts-min.js' id='scripts-js'></script>
# <script type='text/javascript' id='borlabs-cookie-js-extra'>
# /* <![CDATA[ */
# var borlabsCookieConfig = {"ajaxURL":"https:\/\/athleticinterest.com\/wp-admin\/admin-ajax.php","language":"de","animation":"1","animationDelay":"","animationIn":"_brlbs-fadeInUp","animationOut":"_brlbs-fadeOutDown","blockContent":"","boxLayout":"bar","boxLayoutAdvanced":"1","automaticCookieDomainAndPath":"1","cookieDomain":"athleticinterest.com","cookiePath":"\/","cookieSecure":"1","cookieLifetime":"182","cookieLifetimeEssentialOnly":"182","crossDomainCookie":[],"cookieBeforeConsent":"","cookiesForBots":"1","cookieVersion":"1","hideCookieBoxOnPages":[],"respectDoNotTrack":"","reloadAfterConsent":"","reloadAfterOptOut":"1","showCookieBox":"1","cookieBoxIntegration":"javascript","ignorePreSelectStatus":"1","cookies":{"essential":["borlabs-cookie"],"statistics":[],"marketing":[],"external-media":["instagram","twitter","youtube"]}};
# var borlabsCookieCookies = {"essential":{"borlabs-cookie":{"cookieNameList":{"borlabs-cookie":"borlabs-cookie"},"settings":{"blockCookiesBeforeConsent":"0","prioritize":"0"}}},"external-media":{"instagram":{"cookieNameList":{"pigeon_state":"pigeon_state"},"settings":{"blockCookiesBeforeConsent":"0","prioritize":"0"},"optInJS":"PHNjcmlwdD5pZih0eXBlb2Ygd2luZG93LkJvcmxhYnNDb29raWUgPT09ICJvYmplY3QiKSB7IHdpbmRvdy5Cb3JsYWJzQ29va2llLnVuYmxvY2tDb250ZW50SWQoImluc3RhZ3JhbSIpOyB9PC9zY3JpcHQ+","optOutJS":""},"twitter":{"cookieNameList":{"__widgetsettings":"__widgetsettings","local_storage_support_test":"local_storage_support_test"},"settings":{"blockCookiesBeforeConsent":"0","prioritize":"0"},"optInJS":"PHNjcmlwdD5pZih0eXBlb2Ygd2luZG93LkJvcmxhYnNDb29raWUgPT09ICJvYmplY3QiKSB7IHdpbmRvdy5Cb3JsYWJzQ29va2llLnVuYmxvY2tDb250ZW50SWQoInR3aXR0ZXIiKTsgfTwvc2NyaXB0Pg==","optOutJS":""},"youtube":{"cookieNameList":{"NID":"NID"},"settings":{"blockCookiesBeforeConsent":"0","prioritize":"0"},"optInJS":"PHNjcmlwdD5pZih0eXBlb2Ygd2luZG93LkJvcmxhYnNDb29raWUgPT09ICJvYmplY3QiKSB7IHdpbmRvdy5Cb3JsYWJzQ29va2llLnVuYmxvY2tDb250ZW50SWQoInlvdXR1YmUiKTsgfTwvc2NyaXB0Pg==","optOutJS":""}}};
# /* ]]> */
# </script>
# <script type='text/javascript' src='https://athleticinterest.com/wp-content/plugins/borlabs-cookie/assets/javascript/borlabs-cookie.min.js' id='borlabs-cookie-js'></script>
# <script type='text/javascript' id='borlabs-cookie-js-after'>
# document.addEventListener("DOMContentLoaded", function (e) {
# var borlabsCookieContentBlocker = {"default": {"id": "default","global": function (contentBlockerData) {  },"init": function (el, contentBlockerData) {  },"settings": {"executeGlobalCodeBeforeUnblocking":false}},"instagram": {"id": "instagram","global": function (contentBlockerData) {  },"init": function (el, contentBlockerData) { if (typeof instgrm === "object") { instgrm.Embeds.process(); } },"settings": {"executeGlobalCodeBeforeUnblocking":false}},"twitter": {"id": "twitter","global": function (contentBlockerData) {  },"init": function (el, contentBlockerData) {  },"settings": {"executeGlobalCodeBeforeUnblocking":false}},"vimeo": {"id": "vimeo","global": function (contentBlockerData) {  },"init": function (el, contentBlockerData) {  },"settings": {"executeGlobalCodeBeforeUnblocking":false,"saveThumbnails":false,"autoplay":false,"videoWrapper":false}},"youtube": {"id": "youtube","global": function (contentBlockerData) {  },"init": function (el, contentBlockerData) {  },"settings": {"executeGlobalCodeBeforeUnblocking":false,"changeURLToNoCookie":true,"saveThumbnails":false,"autoplay":false,"thumbnailQuality":"maxresdefault","videoWrapper":false}}};
#     var BorlabsCookieInitCheck = function () {
#
#     if (typeof window.BorlabsCookie === "object" && typeof window.jQuery === "function") {
#
#         if (typeof borlabsCookiePrioritized !== "object") {
#             borlabsCookiePrioritized = { optInJS: {} };
#         }
#
#         window.BorlabsCookie.init(borlabsCookieConfig, borlabsCookieCookies, borlabsCookieContentBlocker, borlabsCookiePrioritized.optInJS);
#     } else {
#         window.setTimeout(BorlabsCookieInitCheck, 50);
#     }
# };
#
# BorlabsCookieInitCheck();});
# </script>
#
#
# 	</body>
# </html>

# %%
#Q10
import requests
rt=requests.get(input("Enter url: "))

file=open("D:\Python\q9.txt", "wb").write(rt.content)


file1 = open("D:\Python\q9.txt") 

lines=[]
for line in file1:
    lines.append(line.strip())
print('There are {} strings in the file'.format(len(line)))
# Out:
# Enter url: https://athleticinterest.com/
# There are 8 strings in the file

# %%
#Q11
def split(word):
    return list(word)

word="banana"
#print(split(word))

weight = []
for i in word:
    weight.append(ord(i))
sum(weight)
# Out:
# 609

# %%
#Q12
file2=open("D:\Python\q9.txt")
line=[]
for a in file2:
    line.append(a)
#print('File Content: ', line)
x=0
string= input("enter the string occurence to be searched: ")
for i in range(len(line[0])-len(string)):
    if(line[0][i:i+len(string)] == string):
        x += 1
print('\"{}\" appears {} times in the file'.format(string,x))
# Out:
# enter the string occurence to be searched: meta
# "meta" appears 0 times in the file

# %%
#Q13
from zipfile import ZipFile
with ZipFile("D:\Python\q9.zip", 'w') as zipObj2:
   # Add multiple files to the zip
   zipObj2.write('"D:\Python\q9.zip')

# %%
#Q14
import os
if os.path.exists("D:\Python\q14.txt"):
    os.remove("D:\Python\q14.txt")
else:
    print("The file does not exist")
# Out:
# The file does not exist

# %%
#Q15
import glob
print(glob.glob("D:\Python\*"))
# Out:
# ['D:\\Python\\day1.py', 'D:\\Python\\New folder', 'D:\\Python\\q8.txt', 'D:\\Python\\q9.txt', 'D:\\Python\\q9.zip', 'D:\\Python\\students.csv']

# %%
#Q16
binary = int(input("Enter binary number: "))
print('hex representation:', hex(binary))
print('oct representation: ', oct(binary))
print('binary representation:', binary)
# Out:
# Enter binary number: 110110
# hex representation: 0x1ae1e
# oct representation:  0o327036
# binary representation: 110110

# %%
#Q17
for i in range(1,101,):
    if i%15==0:
        print("fizzbuzz")
    elif i%3==0:
        print("fizz")
    elif i%5==0:
        print("buzz")
    else:
        print(i)
# Out:
# 1
# 2
# fizz
# 4
# buzz
# fizz
# 7
# 8
# fizz
# buzz
# 11
# fizz
# 13
# 14
# fizzbuzz
# 16
# 17
# fizz
# 19
# buzz
# fizz
# 22
# 23
# fizz
# buzz
# 26
# fizz
# 28
# 29
# fizzbuzz
# 31
# 32
# fizz
# 34
# buzz
# fizz
# 37
# 38
# fizz
# buzz
# 41
# fizz
# 43
# 44
# fizzbuzz
# 46
# 47
# fizz
# 49
# buzz
# fizz
# 52
# 53
# fizz
# buzz
# 56
# fizz
# 58
# 59
# fizzbuzz
# 61
# 62
# fizz
# 64
# buzz
# fizz
# 67
# 68
# fizz
# buzz
# 71
# fizz
# 73
# 74
# fizzbuzz
# 76
# 77
# fizz
# 79
# buzz
# fizz
# 82
# 83
# fizz
# buzz
# 86
# fizz
# 88
# 89
# fizzbuzz
# 91
# 92
# fizz
# 94
# buzz
# fizz
# 97
# 98
# fizz
# buzz

# %%
#Q20
class Car:
    def __init__(self, company, model, gear, CC, color, has_abs):
        self.company = company
        self.model = model
        self.gear = gear
        self.CC = CC
        self.color = color
        self.has_abs = has_abs
        
    def know_color(self):
        return self.color
    
    
BMW = Car('BMW','X34','No','2000', 'Black', True)
BMW.know_color()
# Out:
# 'Black'
